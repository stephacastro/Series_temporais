# %% [markdown]
# # Importação de Arquivo CSV - Estudos part2 Séries Temporais

# %%
import pandas as pd
import numpy as np

# %%
# Importando arquivo com separador por ,
df = pd.read_csv('C:\\Series_Temporais\\UDEMY_TSA_FINAL\\SeriesTemporais\\seriestemporaisPython\\scripts e dados\\Download\Dados\\Resp2.csv')
df.head(6)
# Out:
#    experience  respiration
# 0           0         3.94
# 1           0         4.26
# 2           0         4.16
# 3           0         3.76
# 4           0         4.07
# 5           0         3.57

# %%
# Importando arquivo com separador por ;
df1 = pd.read_csv('C:\\Series_Temporais\\UDEMY_TSA_FINAL\\SeriesTemporais\\seriestemporaisPython\\scripts e dados\\Download\Dados\\winequality-red.csv', sep=';')
df1.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
# Importando arquivo separado por tabulação
df2 = pd.read_csv('C:\\Series_Temporais\\UDEMY_TSA_FINAL\\SeriesTemporais\\seriestemporaisPython\\scripts e dados\\Download\Dados\\bostonTxt.txt', sep='\t')
df2.head(10)
# Out:
#      MV  INDUS   NOX     RM  TAX    PT  LSTAT
# 0  24.0   2.31  53.8  6.575  296  15.3   4.98
# 1  21.6   7.07  46.9  6.421  242  17.8   9.14
# 2  34.7   7.07  46.9  7.185  242  17.8   4.03
# 3  33.4   2.18  45.8  6.998  222  18.7   2.94
# 4  36.2   2.18  45.8  7.147  222  18.7   5.33
# 5  28.7   2.18  45.8  6.430  222  18.7   5.21
# 6  22.9   7.87  52.4  6.012  311  15.2  12.43
# 7  27.1   7.87  52.4  6.172  311  15.2  19.15
# 8  16.5   7.87  52.4  5.631  311  15.2  29.93
# 9  18.9   7.87  52.4  6.004  311  15.2  17.10
